# %%
import pytearcat as pt

t,r,theta,phi = pt.coords('t,r,theta,phi')
A = pt.fun('A','t,r')
N = pt.fun('N','t,r')

ds = 'ds2 = -A**2*N*dt**2 + dr**2/N + r**2*(dtheta**2 + sin(theta)**2*dphi**2)'
g = pt.metric(ds)
# Out:
# Remember that the time coordinate must be the first coordinate.
#
# Dimension = 4
# Coordinates = t,r,theta,phi
# Metric defined successfully:
# $\displaystyle ds^2 = - A^{2}{\left(t,r \right)} N{\left(t,r \right)} \cdot dt^2+\frac{1}{N{\left(t,r \right)}} \cdot dr^2+r^{2} \cdot d\theta^2+r^{2} \sin^{2}{\left(\theta \right)} \cdot d\phi^2$
# Matrix([
# [-A(t, r)**2*N(t, r),         0,    0,                  0],
# [                  0, 1/N(t, r),    0,                  0],
# [                  0,         0, r**2,                  0],
# [                  0,         0,    0, r**2*sin(theta)**2]])

# %%
G = pt.einstein()
G.simplify()
G.display()
# Out:
# Christoffel $\Gamma_{\alpha \beta \gamma}$ and $\Gamma^{\alpha}_{\beta \gamma}$
#   0%|          | 0/64 [00:00<?, ?it/s]
# Riemann Tensor $R^{\alpha}_{\beta \gamma \delta}$
#   0%|          | 0/256 [00:00<?, ?it/s]
# Ricci Tensor $R_{\alpha \beta}$
# ...
#   0%|          | 0/16 [00:00<?, ?it/s]
# Ricci Scalar $R$
# Einstein Tensor $G_{\alpha \beta}$
#   0%|          | 0/16 [00:00<?, ?it/s]
# ⎡⎛    ∂                        ⎞  2                                 ∂                                                  ↪
# ⎢⎜- r⋅──(N(t, r)) - N(t, r) + 1⎟⋅A (t, r)⋅N(t, r)                  -──(N(t, r))                                        ↪
# ⎢⎝    ∂r                       ⎠                                    ∂t                                                 ↪
# ⎢────────────────────────────────────────────────                  ─────────────                                       ↪
# ...
